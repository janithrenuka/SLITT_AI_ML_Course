# %% [markdown]
# 1.1 Import Data

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/janithrenuka/SLITT_AI_ML_Course/main/Mobile_Price_Classification-220531-204702.csv"
pf = pd.read_csv(url)
pf.head(5)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# 1.2 Define x, y

# %%
x = pf.drop(['price_range'],axis=1)
y = pf['price_range']
print(y)
# Out:
# 0       1
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 1995    0
# 1996    0
# 1997    1
# 1998    0
# 1999    1
# Name: price_range, Length: 2000, dtype: int64

# %% [markdown]
# 2. sklearn model to train data
# test size is 0.25 from all data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1257           1449     1          0.5         1   0       0          52
# 1062            587     1          2.5         0  16       1          51
# 1474           1617     1          2.6         0  14       0          29
# 1179           1880     0          0.5         0   0       1           7
# 1593           1864     0          2.2         0   0       1           7
# ...             ...   ...          ...       ...  ..     ...         ...
# 622            1225     0          0.7         1   0       1           2
# 626            1620     1          2.2         1   0       1          30
# 688            1314     0          2.9         1   8       1          41
# 1575            625     0          2.7         1   2       0          42
# 1493           1183     1          0.5         1   3       1          48
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# 3.1 Import Dependenies

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout

# %% [markdown]
# 3.2 Build Model

# %%
model=Sequential()
model.add(Dense(units=8,activation='relu',input_dim=len(x_train.columns)))
model.add(Dense(units=4,activation='relu'))
model.add(Dense(units=1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_5 (Dense)             (None, 8)                 168
#
#  dense_6 (Dense)             (None, 4)                 36
#
#  dense_7 (Dense)             (None, 1)                 5
#
# ...
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4. Compile the model

# %%
model.compile(loss='binary_crossentropy',optimizer='sgd',metrics='accuracy')

# %% [markdown]
# 5. Fit, train the model

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),epochs=100,batch_size=32)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 6ms/step - loss: 126.9523 - accuracy: 0.4853 - val_loss: 0.6931 - val_accuracy: 0.4960
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.4880 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 3/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6932 - accuracy: 0.4920 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 4/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 5/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.6932 - accuracy: 0.4893 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 6/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.6932 - accuracy: 0.5013 - val_loss: 0.6932 - val_accuracy: 0.4960
# Epoch 7/100
# ...

# %% [markdown]
# 6. Save the weight file

# %%
model.save('weights.h5')
